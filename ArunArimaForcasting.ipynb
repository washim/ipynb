# %%
.libPaths("/home/washim/R/x86_64-pc-linux-gnu-library/3.4")
library(forecast)

# %%
data <- read.csv("monthly-hotel-occupied-room-av-6.csv", stringsAsFactors = F)
data <- data[1:168,]
tsdata <- ts(data[,2], frequency = 12, start = c(1963,1))

# %%
plot(tsdata)
# Out:
# plot without title

# %%
plot(log(tsdata))
# Out:
# plot without title

# %%
plot(diff(log(tsdata)))
# Out:
# plot without title

# %%
acf(diff(log(tsdata)))
# Out:
# Plot with title “Series  diff(log(tsdata))”

# %%
pacf(diff(log(tsdata)), lag.max = 50)
# Out:
# Plot with title “Series  diff(log(tsdata))”

# %%
fit <- arima(log(tsdata),c(1,1,1),seasonal = list(order=c(1,1,1), period = 12))

# %%
BIC(fit)
# Out:
# [1] -740.205

# %%
fit1 <- arima(log(tsdata),c(0,1,1),seasonal = list(order=c(0,1,1), period = 12))
BIC(fit1)
# Out:
# [1] -741.7351
